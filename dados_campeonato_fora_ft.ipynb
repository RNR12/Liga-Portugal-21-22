# %% [markdown]
# <h1 style="font-size:3rem;color:orange;">Dados Campeonato Liga Portugal 21-22 </h1>

# %% [markdown]
# # Dados estatísticos de jogos fora do campeonato

# %% [markdown]
# <img src="https://www.ligaportugal.pt/media/33648/logo-lpbwin.png?anchor=center&mode=crop&width=647&height=485&rnd=132727202950000000">

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Para sabermos a classificação final a jogar fora do campeonato 
df=pd.read_csv("classificaçao_fora.csv", header=0)
df.head(18)
# Out:
#                equipa  jogos_jogados  vitorias  empates  derrotas  \
# 0               Porto             17        14        2         1
# 1         Sporting CP             17        13        3         1
# 2             Benfica             17        13        2         2
# 3      Sporting Braga             17         9        4         4
# 4         Gil Vicente             17         7        6         4
# 5        Portimonense             17         6        4         7
# 6         CS Maritimo             17         5        5         7
# 7    GD Estoril Praia             17         5        4         8
# 8   Vitoria Guimaraes             17         4        6         7
# 9           Famalicao             17         4        5         8
# 10  Pacos de Ferreira             17         4        5         8
# 11        Boavista FC             17         3        7         7
# 12          FC Vizela             17         3        5         9
# ...

# %%
#Qual o pódio deste campeonato se apenas forem contabilizados os jogos fora?
podio = df[['equipa', 'pontos']]
podio.head(3)
# Out:
#         equipa  pontos
# 0        Porto      44
# 1  Sporting CP      42
# 2      Benfica      41

# %%
#Qual foi a melhor equipa a jogar fora este campeonato? Com quantas V/E/D, pontos e golos sofridos e marcados?
df.head(1)
# Out:
#   equipa  jogos_jogados  vitorias  empates  derrotas  golos_marcados  \
# 0  Porto             17        14        2         1              36
#
#    golos_sofridos  diferenca_golos  pontos
# 0              11               25      44

# %%
#Qual é a média de pontos ganhos em jogos fora pelas equipas por cada jornada?

pd.options.display.float_format = '{:,.3f}'.format
avg_pontos = df["pontos"] / 17
avg_pontos
df["avg_pontos"] = df["pontos"] /17
result = df[["equipa", "avg_pontos"]]
result
# Out:
#                equipa  avg_pontos
# 0               Porto       2.588
# 1         Sporting CP       2.471
# 2             Benfica       2.412
# 3      Sporting Braga       1.824
# 4         Gil Vicente       1.588
# 5        Portimonense       1.294
# 6         CS Maritimo       1.176
# 7    GD Estoril Praia       1.118
# 8   Vitoria Guimaraes       1.059
# 9           Famalicao       1.000
# 10  Pacos de Ferreira       1.000
# 11        Boavista FC       0.941
# 12          FC Vizela       0.824
# 13          FC Arouca       0.706
# 14         CD Tondela       0.706
# 15      Moreirense FC       0.647
# 16        Santa Clara       0.588
# 17     Belenenses SAD       0.471

# %%
#Qual é a média de golos marcados em jogos fora pelas equipas ao longo do campeonato

pd.options.display.float_format = '{:,.3f}'.format
avg_golos_marcados = df["golos_marcados"] / 17
avg_golos_marcados
df["avg_golos_marcados"] = df["golos_marcados"] /17
result = df[["equipa", "avg_golos_marcados"]]
result
# Out:
#                equipa  avg_golos_marcados
# 0               Porto               2.118
# 1         Sporting CP               2.294
# 2             Benfica               2.471
# 3      Sporting Braga               1.471
# 4         Gil Vicente               1.294
# 5        Portimonense               0.941
# 6         CS Maritimo               1.176
# 7    GD Estoril Praia               0.882
# 8   Vitoria Guimaraes               0.941
# 9           Famalicao               1.353
# 10  Pacos de Ferreira               0.588
# 11        Boavista FC               1.118
# 12          FC Vizela               1.235
# 13          FC Arouca               0.882
# 14         CD Tondela               1.000
# 15      Moreirense FC               0.647
# 16        Santa Clara               0.824
# 17     Belenenses SAD               0.471

# %%
#Qual é a média de golos sofridos em jogos fora pelas equipas ao longo do campeonato

pd.options.display.float_format = '{:,.3f}'.format
avg_golos_sofridos = df["golos_sofridos"] / 17
avg_golos_sofridos
df["avg_golos_sofridos"] = df["golos_sofridos"] /17
result = df[["equipa", "avg_golos_sofridos"]]
result
# Out:
#                equipa  avg_golos_sofridos
# 0               Porto               0.647
# 1         Sporting CP               0.882
# 2             Benfica               0.824
# 3      Sporting Braga               1.059
# 4         Gil Vicente               1.353
# 5        Portimonense               1.353
# 6         CS Maritimo               1.588
# 7    GD Estoril Praia               1.294
# 8   Vitoria Guimaraes               1.235
# 9           Famalicao               1.765
# 10  Pacos de Ferreira               1.294
# 11        Boavista FC               1.882
# 12          FC Vizela               2.176
# 13          FC Arouca               1.471
# 14         CD Tondela               2.000
# 15      Moreirense FC               1.647
# 16        Santa Clara               1.824
# 17     Belenenses SAD               1.471

# %%
#Qual foi a equipa que mais golos marcou fora (melhor ataque forasteiro) nesta edição do campeonato?

print(df['golos_marcados'].max())
golos_m = df['golos_marcados'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 42
# Benfica

# %%
#Qual foi a equipa que mais golos sofreu fora (pior defesa forasteira) nesta edição do campeonato?

print(df['golos_sofridos'].max())
golos_m = df['golos_sofridos'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 37
# FC Vizela

# %%
#Qual foi a equipa com o maior número de vitórias forasteiras nesta edição do campeonato?
print(df['vitorias'].max())
golos_m = df['vitorias'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 14
# Porto

# %%
#Qual foi a equipa com o maior número de empates forasteiros nesta edição do campeonato?
print(df['empates'].max())
golos_m = df['empates'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 8
# Belenenses SAD

# %%
#Qual foi a equipa com o maior número de derrotas forasteiras nesta edição do campeonato?
print(df['derrotas'].max())
golos_m = df['derrotas'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 11
# CD Tondela

# %%
#Top 5 de equipas com mais golos marcados fora

df.sort_values(by = ["golos_marcados"], inplace =False, ascending=False).head()
# Out:
#            equipa  jogos_jogados  vitorias  empates  derrotas  golos_marcados  \
# 2         Benfica             17        13        2         2              42
# 1     Sporting CP             17        13        3         1              39
# 0           Porto             17        14        2         1              36
# 3  Sporting Braga             17         9        4         4              25
# 9       Famalicao             17         4        5         8              23
#
#    golos_sofridos  diferenca_golos  pontos
# 2              14               28      41
# 1              15               24      42
# 0              11               25      44
# 3              18                7      31
# 9              30               -7      17

# %%
#Top 5 de equipas com mais golos sofridos fora

df.sort_values(by = ["golos_sofridos"], inplace =False, ascending=False).head()
# Out:
#          equipa  jogos_jogados  vitorias  empates  derrotas  golos_marcados  \
# 12    FC Vizela             17         3        5         9              21
# 14   CD Tondela             17         3        3        11              17
# 11  Boavista FC             17         3        7         7              19
# 16  Santa Clara             17         1        7         9              14
# 9     Famalicao             17         4        5         8              23
#
#     golos_sofridos  diferenca_golos  pontos
# 12              37              -16      14
# 14              34              -17      12
# 11              32              -13      16
# 16              31              -17      10
# 9               30               -7      17

# %%
#Gráfico de golos marcados fora pelas equipas ao longo do campeonato

_ = plt.figure(figsize=(10,8))
_ = plt.bar(df["equipa"], df["golos_marcados"],align = "center", color=("green"))
_ = plt.xlabel("Equipas")
_ = plt.ylabel("Golos Marcados")
_ = plt.xticks(rotation = 90)
_ = plt.title("Golos marcados em jogos fora na Liga Portugal 21-22")
plt.show()

# %%
#Gráfico de golos sofridos fora pelas equipas ao longo do campeonato

_ = plt.figure(figsize=(10,8))
_ = plt.bar(df["equipa"], df["golos_sofridos"],align = "center", color=("red"))
_ = plt.xlabel("Equipas")
_ = plt.ylabel("Golos Sofridos")
_ = plt.xticks(rotation = 90)
_ = plt.title("Golos sofridos em jogos fora na Liga Portugal 21-22")
plt.show()

# %%
#Gráfico da pontuação final (apenas contabilizando os jogos fora) do campeonato 

_ = plt.figure(figsize=(10,8))
_ = plt.bar(df["equipa"], df["pontos"],align = "center", color=("black"))
_ = plt.xlabel("Equipas")
_ = plt.ylabel("Pontos")
_ = plt.xticks(rotation = 90)
_ = plt.title("Pontuação final (apenas contabilizando os jogos fora) da Liga Portugal 21-22")
plt.show()
