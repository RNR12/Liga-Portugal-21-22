# %% [markdown]
# <h1 style="font-size:3rem;color:orange;">Dados Campeonato Liga Portugal 21-22 </h1>

# %% [markdown]
# # Dados estatísticos gerais do campeonato

# %% [markdown]
# <img src="https://www.ligaportugal.pt/media/33648/logo-lpbwin.png?anchor=center&mode=crop&width=647&height=485&rnd=132727202950000000">

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Para sabermos a classificação final do campeonato 
df=pd.read_csv("classificaçao.csv", header=0)
df.head(18)
# Out:
#                equipa  jogos_jogados  vitorias  empates  derrotas  \
# 0            FC Porto             34        29        4         1
# 1            Sporting             34        27        4         3
# 2             Benfica             34        23        5         6
# 3               Braga             34        19        8         7
# 4         Gil Vicente             34        13       12         9
# 5        V. Guimaraes             34        13        9        12
# 6         Santa Clara             34         9       13        12
# 7           Famalicao             34         9       12        13
# 8             Estoril             34         9       12        13
# 9            Maritimo             34         9       11        14
# 10  Pacos de Ferreira             34         9       11        14
# 11           Boavista             34         7       17        10
# 12       Portimonense             34        10        8        16
# ...

# %%
#Qual foi o pódio deste campeonato nacional?
podio = df[['equipa', 'pontos']]
podio.head(3)
# Out:
#      equipa  pontos
# 0  FC Porto      91
# 1  Sporting      85
# 2   Benfica      74

# %%
#Quem foi o campeão deste campeonato? Com quantas V/E/D, pontos e golos sofridos e marcados?
df.head(1)
# Out:
#      equipa  jogos_jogados  vitorias  empates  derrotas  golos_marcados  \
# 0  FC Porto             34        29        4         1              86
#
#    golos_sofridos  diferenca_golos  pontos
# 0              22               64      91

# %%
#Qual é a média de pontos ganhos pelas equipas por cada jornada?

pd.options.display.float_format = '{:,.3f}'.format
avg_pontos = df["pontos"] / 34
avg_pontos
df["avg_pontos"] = df["pontos"] /34
result = df[["equipa", "avg_pontos"]]
result
# Out:
#                equipa  avg_pontos
# 0            FC Porto       2.676
# 1            Sporting       2.500
# 2             Benfica       2.176
# 3               Braga       1.912
# 4         Gil Vicente       1.500
# 5        V. Guimaraes       1.412
# 6         Santa Clara       1.176
# 7           Famalicao       1.147
# 8             Estoril       1.147
# 9            Maritimo       1.118
# 10  Pacos de Ferreira       1.118
# 11           Boavista       1.118
# 12       Portimonense       1.118
# 13             Vizela       0.971
# 14             Arouca       0.912
# 15         Moreirense       0.853
# 16            Tondela       0.824
# 17     Belenenses SAD       0.765

# %%
#Qual é a média de golos marcados por jogo pelas equipas ao longo do campeonato

pd.options.display.float_format = '{:,.3f}'.format
avg_golos_marcados = df["golos_marcados"] / 34
avg_golos_marcados
df["avg_golos_marcados"] = df["golos_marcados"] /34
result = df[["equipa", "avg_golos_marcados"]]
result
# Out:
#                equipa  avg_golos_marcados
# 0            FC Porto               2.529
# 1            Sporting               2.147
# 2             Benfica               2.294
# 3               Braga               1.529
# 4         Gil Vicente               1.382
# 5        V. Guimaraes               1.471
# 6         Santa Clara               1.118
# 7           Famalicao               1.324
# 8             Estoril               1.059
# 9            Maritimo               1.147
# 10  Pacos de Ferreira               0.853
# 11           Boavista               1.147
# 12       Portimonense               0.912
# 13             Vizela               1.088
# 14             Arouca               0.882
# 15         Moreirense               0.971
# 16            Tondela               1.206
# 17     Belenenses SAD               0.676

# %%
#Qual é a média de golos sofridos por jogo pelas equipas ao longo do campeonato

pd.options.display.float_format = '{:,.3f}'.format
avg_golos_sofridos = df["golos_sofridos"] / 34
avg_golos_sofridos
df["avg_golos_sofridos"] = df["golos_sofridos"] /34
result = df[["equipa", "avg_golos_sofridos"]]
result
# Out:
#                equipa  avg_golos_sofridos
# 0            FC Porto               0.647
# 1            Sporting               0.676
# 2             Benfica               0.882
# 3               Braga               0.912
# 4         Gil Vicente               1.235
# 5        V. Guimaraes               1.206
# 6         Santa Clara               1.588
# 7           Famalicao               1.500
# 8             Estoril               1.265
# 9            Maritimo               1.294
# 10  Pacos de Ferreira               1.294
# 11           Boavista               1.529
# 12       Portimonense               1.324
# 13             Vizela               1.706
# 14             Arouca               1.588
# 15         Moreirense               1.500
# 16            Tondela               1.971
# 17     Belenenses SAD               1.618

# %%
#Qual foi a equipa que mais golos marcou (melhor ataque) nesta edição do campeonato?

print(df['golos_marcados'].max())
golos_m = df['golos_marcados'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 86
# FC Porto

# %%
#Qual foi a equipa que mais golos sofreu (pior defesa) nesta edição do campeonato?

print(df['golos_sofridos'].max())
golos_m = df['golos_sofridos'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 67
# Tondela

# %%
#Qual foi a equipa com o maior número de vitórias nesta edição do campeonato?
print(df['vitorias'].max())
golos_m = df['vitorias'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 29
# FC Porto

# %%
#Qual foi a equipa com o maior número de empates nesta edição do campeonato?
print(df['empates'].max())
golos_m = df['empates'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 17
# Boavista

# %%
#Qual foi a equipa com o maior número de derrotas nesta edição do campeonato?
print(df['derrotas'].max())
golos_m = df['derrotas'].idxmax()
print(df['equipa'][golos_m])
# Out:
# 20
# Tondela

# %%
#Top 5 de equipas com mais golos marcados

df.sort_values(by = ["golos_marcados"], inplace =False, ascending=False).head()
# Out:
#          equipa  jogos_jogados  vitorias  empates  derrotas  golos_marcados  \
# 0      FC Porto             34        29        4         1              86
# 2       Benfica             34        23        5         6              78
# 1      Sporting             34        27        4         3              73
# 3         Braga             34        19        8         7              52
# 5  V. Guimaraes             34        13        9        12              50
#
#    golos_sofridos  diferenca_golos  pontos
# 0              22               64      91
# 2              30               48      74
# 1              23               50      85
# 3              31               21      65
# 5              41                9      48

# %%
#Top 5 de equipas com mais golos sofridos

df.sort_values(by = ["golos_sofridos"], inplace =False, ascending=False).head()
# Out:
#             equipa  jogos_jogados  vitorias  empates  derrotas  \
# 16         Tondela             34         7        7        20
# 13          Vizela             34         7       12        15
# 17  Belenenses SAD             34         5       11        18
# 14          Arouca             34         7       10        17
# 6      Santa Clara             34         9       13        12
#
#     golos_marcados  golos_sofridos  diferenca_golos  pontos
# 16              41              67              -26      28
# 13              37              58              -21      33
# 17              23              55              -32      26
# 14              30              54              -24      31
# 6               38              54              -16      40

# %%
#Gráfico de golos marcados pelas equipas (casa e fora) ao longo do campeonato
_ = plt.figure(figsize=(10,8))
_ = plt.bar(df["equipa"], df["golos_marcados"],align = "center", color=("green"))
_ = plt.xlabel("Equipas")
_ = plt.ylabel("Golos Marcados")
_ = plt.xticks(rotation = 90)
_ = plt.title("Golos marcados na Liga Portugal 21-22")
plt.show()

# %%
#Gráfico de golos sofridos (casa e fora) pelas equipas ao longo do campeonato
_ = plt.figure(figsize=(10,8))
_ = plt.bar(df["equipa"], df["golos_sofridos"],align = "center", color=("red"))
_ = plt.xlabel("Equipas")
_ = plt.ylabel("Golos Sofridos")
_ = plt.xticks(rotation = 90)
_ = plt.title("Golos sofridos na Liga Portugal 21-22")
plt.show()

# %%
#Gráfico da pontuação final do campeonato 

_ = plt.figure(figsize=(10,8))
_ = plt.bar(df["equipa"], df["pontos"],align = "center", color=("black"))
_ = plt.xlabel("Equipas")
_ = plt.ylabel("Pontos")
_ = plt.xticks(rotation = 90)
_ = plt.title("Pontuação final da Liga Portugal 21-22")
plt.show()
